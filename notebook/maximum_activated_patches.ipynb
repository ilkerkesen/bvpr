# %%
from bvpr.visualization import MaximumActivatedPatchesDemo as Demo
from bvpr.util import sizes2scales, scales2sizes
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
import torch.nn.functional as F

# %%
DATASET = "unc"
DATA_PATH = "~/data/refexp/data"
CHECKPOINT_PATH = "~/model.ckpt"
DEVICE = "cuda:0"
THRESHOLD = 0.40

demo = Demo(
    checkpoint_path=CHECKPOINT_PATH,
    threshold=THRESHOLD,
    data_path=DATA_PATH,
    dataset=DATASET,
    device=DEVICE
)

# %%
EXAMPLE_ID = 1235
DATASPLIT_ID = 1
PHRASE = "back bear"

demo.visualize(EXAMPLE_ID, datasplit_id=DATASPLIT_ID, custom_phrase=PHRASE)
# Out:
# phrase: back bear

# %%
EXAMPLE_ID = 1235
DATASPLIT_ID = 1
PHRASE = "front bear"

demo.visualize(EXAMPLE_ID, datasplit_id=DATASPLIT_ID, custom_phrase=PHRASE)
# Out:
# phrase: front bear
