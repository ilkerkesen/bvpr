# %%
from bvpr.visualization import ColorizationDemo

# %%
DATA_PATH = "/userfiles/ikesen16/data/colorization"
CHECKPOINT_PATH = "/kuacc/users/ikesen16/logs/bvpr/colors/ColorizationModel-colors/faster-fixed/checkpoints/last.ckpt"
DEVICE = "cuda:0"

demo = ColorizationDemo(
    checkpoint_path=CHECKPOINT_PATH,
    data_path=DATA_PATH,
    device=DEVICE
)
# Out:
# /scratch/users/ikesen16/repos/me/bvpr/bvpr/util.py:173: RuntimeWarning: divide by zero encountered in reciprocal
#   prior_factor = prior_mix**-alpha

# %%
demo.visualize(96290, custom_caption="a dog sitting on a blue sofa", T=0.38)
# Out:
# caption: a dog sitting on a blue sofa
# top-1: 0.01983019709587097, top-5: 0.0920758917927742

# %%
demo.visualize(5157, custom_caption="A woman in leather pants posing on a blue motorcycle.", T=0.38)
# Out:
# /kuacc/users/ikesen16/miniconda3/lib/python3.8/site-packages/skimage/color/colorconv.py:1109: UserWarning: Color data out of range: Z < 0 in 615 pixels
#   return xyz2rgb(lab2xyz(lab, illuminant, observer))
# caption: A woman in leather pants posing on a blue motorcycle.
# top-1: 0.14706233143806458, top-5: 0.2639508843421936
