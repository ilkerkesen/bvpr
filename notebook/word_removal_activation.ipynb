# %%
from bvpr.visualization import WordRemovalActivationDemo as Demo

# %%
DATASET = "unc"
DATA_PATH = "~/data/refexp/data"
CHECKPOINT_PATH = "~/model.ckpt"
DEVICE = "cuda:0"
THRESHOLD = 0.40

demo = Demo(
    checkpoint_path=CHECKPOINT_PATH,
    threshold=THRESHOLD,
    data_path=DATA_PATH,
    dataset=DATASET,
    device=DEVICE
)

# %%
EXAMPLE_ID = 1235
DATASPLIT_ID = 1
PHRASE = None

demo.visualize(EXAMPLE_ID, datasplit_id=DATASPLIT_ID, custom_phrase=PHRASE)
# Out:
# phrase: back bear
